# %% [markdown]
# ## Load API keys

# %%
import os
import yaml
import pandas as pd
import requests
import json
import time
import random
from datetime import datetime, timedelta

from IPython.display import clear_output

# %%
def load_api_keys(yaml_path=None):
    """
    Load API keys from a YAML file.

    :param yaml_path: Path to the YAML file (optional).
    :return: A dictionary with API keys.
    """
    # Default path to the keys.yml file
    if not yaml_path:
        yaml_path = os.path.expanduser("../project_keys.yml")
    
    try:
        with open(yaml_path, 'r') as file:
            data = yaml.safe_load(file)
            return data.get('api_keys', {})
    except FileNotFoundError:
        raise FileNotFoundError(f"API keys file not found at: {yaml_path}")
    except yaml.YAMLError as e:
        raise Exception(f"Error parsing YAML file: {e}")

# %%
# Load API keys
api_keys = load_api_keys()

# Access individual keys
flightradar_key = api_keys.get('Flightradar24_flight-lab-01')

# %% [markdown]
# ## Flightradar API requests

# %% [markdown]
# #### REGA Aircraft List

# %%
rega_heli_regs = ['HB-ZRN',
                  'HB-ZRP',
                  'HB-ZRQ',
                  'HB-ZRR',
                  'HB-ZRS',
                  'HB-ZRT',
                  'HB-ZQO',
                  'HB-ZRU',
                  'HB-ZRW',
                  'HB-ZRX',
                  'HB-ZRY',
                  'HB-ZRZ',
                  'HB-ZRJ',
                  'HB-TIB',
                  'HB-ZQI',
                  'HB-ZQJ',
                  'HB-ZQL',
                  'HB-ZQM',
                  'HB-ZQN']

rega_airplane_regs = ['HB-JWC',
                      'HB-JWA',
                      'HB-JWB']

rega_ac_regs = rega_heli_regs + rega_airplane_regs

print(len(rega_heli_regs))
print(len(rega_airplane_regs))
print(len(rega_ac_regs))

rega_ac_regs_string = ''
for reg in rega_ac_regs :
    rega_ac_regs_string += reg + ','

rega_ac_regs_string
# Out:
# 19
# 3
# 22
# 'HB-ZRN,HB-ZRP,HB-ZRQ,HB-ZRR,HB-ZRS,HB-ZRT,HB-ZQO,HB-ZRU,HB-ZRW,HB-ZRX,HB-ZRY,HB-ZRZ,HB-ZRJ,HB-TIB,HB-ZQI,HB-ZQJ,HB-ZQL,HB-ZQM,HB-ZQN,HB-JWC,HB-JWA,HB-JWB,'

# %% [markdown]
# ## Flight positions
#
# - **I have 3'397'535 credits remaining**
# - **Run one year every 5 minutes -> Expected queries at 8 credits per query (60/5)x24x365x8 = 840'960 credits**
# - **One year at 5m intervals would take approx. 29h**
# - **Assess how many individual missions this gets me per year and validate credit usage for the number of queries**
# - **See how many years I can do with full mission track data given 2'500'000 credits affords 62'500 missions worth of tracks, approx. 8 per day per registration (62'500 missions would take about 16h to pull once I have the flight IDs)**
#
# ### CREDITS NOTE: Consider doing just 2024 in review for REGA and using the rest for Pilatus (considering about 4000 SNs for Pilatus...)

# %%
def rega_flight_positions(flightradar_key,rega_ac_regs_string,save_path_root,start_date,end_date,splits_per_hour) :
  # API Parameters
  API_TOKEN = flightradar_key
  url = "https://fr24api.flightradar24.com/api/historic/flight-positions/full"
  
  params = {
    'registrations': rega_ac_regs_string #	Aircraft registration numbers (comma-separated values)
  }

  headers = {
          'Accept': 'application/json',
          'Accept-Version': 'v1',
          'Authorization': f'Bearer {API_TOKEN}',
          }

  # Define Save Path
  progress_save_path = "../data/raw" + "/progress_and_errors" + save_path_root.split("../data/raw")[1]
  last_progress_save = "No progress save yet"

  # Define date ranges
  dates = pd.date_range(start=start_date, end=end_date, freq='h')
  query_no = 0

  # Initialize the DataFrame to store data
  df_flight_position = pd.DataFrame()

  # Loop through the dates and timestamps to search for REGA data in API
  for j, date in enumerate(dates): 
    timestamps = []

    # Generate the timestamps for the hour based on the splits per hour
    for split in range(splits_per_hour):
      minute = int((60/splits_per_hour) * split)
      timestamp = int(datetime(date.year, date.month, date.day, date.hour, minute).timestamp())  # Generate the timestamp for the hour
      timestamps.append(timestamp)
    
    # Loop through the timestamps
    for k, timestamp in enumerate(timestamps): 
        query_no += 1
        time.sleep(0.67) 
        params['timestamp'] = timestamp 
        
        # Debugging line
        clear_output(wait=True)    
        print(f"Date range from {start_date} to {end_date}")
        print(f"Query {query_no} of expected {len(timestamps)*len(dates)}")
        print(last_progress_save)
        print(f"Date {j+1} of {len(dates)} and Timestamp {k+1} of {len(timestamps)}")
        print(f"Requesting on date {date} at timestamp {timestamp}") 

        try:
            response = requests.get(url, headers=headers, params=params)
            response.raise_for_status()
            data = response.json()

            if isinstance(data, dict) and "data" in data and isinstance(data["data"], list) and data["data"]:
              print(json.dumps(data, indent=4))  # Debugging line
              # If data is found, append it to the DataFrame
              df_flight_position = pd.concat([df_flight_position, pd.DataFrame(data["data"])], ignore_index=True)

            else:
              print(f"No data found for date {date} at timestamp {timestamp}")
              
        except requests.exceptions.HTTPError as http_err:
              print(f"HTTP error occurred: {http_err}")
              time_of_error = int(time.time())
              save_path = progress_save_path + str(time_of_error) + "_http_error.csv"
              df_flight_position.to_csv(save_path, index=False)
  
        except Exception as err:
              print(f"An error occurred: {err}")
              time_of_error = int(time.time())
              save_path = progress_save_path + str(time_of_error) + "_error.csv"
              df_flight_position.to_csv(save_path, index=False)
    
    # In loop progress saving for every 7th day in date range
    if (query_no) % (7*24*splits_per_hour) == 0 :
      time_of_progress_save = int(time.time())
      save_path = progress_save_path + str(date) + "_" + str(time_of_progress_save) + ".csv"
      df_flight_position.to_csv(save_path, index=False)
      last_progress_save = f"The last progress save was on {str(date)} at {str(time_of_progress_save)}"

  # Final Saving
  time_of_run = int(time.time())
  save_path = save_path_root + str(splits_per_hour) + "_splitsperhour_final_" + str(time_of_run) + ".csv"
  df_flight_position.to_csv(save_path, index=False)

  print("GREAT SUCCESS!!!!!!!!!!")
  return df_flight_position

# %%
save_path_root = "../data/raw/df_flight_position_20221201_20231231_" # No need to end with .csv, leave as "_" for timestamp
start_date = datetime(2023, 11, 16, 0, 0, 0)
end_date = datetime(2023, 12, 31, 23, 59, 59)
splits_per_hour = 12

rega_flight_positions = rega_flight_positions(flightradar_key,rega_ac_regs_string,save_path_root,start_date,end_date,splits_per_hour)
# Out:
# Date range from 2023-11-16 00:00:00 to 2023-12-31 23:59:59
# Query 177 of expected 13248
# No progress save yet
# Date 15 of 1104 and Timestamp 9 of 12
# Requesting on date 2023-11-16 14:00:00 at timestamp 1700142000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 6
#       3 end_date = datetime(2023, 12, 31, 23, 59, 59)
#       4 splits_per_hour = 12
# ----> 6 rega_flight_positions = rega_flight_positions(flightradar_key,rega_ac_regs_string,save_path_root,start_date,end_date,splits_per_hour)
#
# Cell In[5], line 52, in rega_flight_positions(flightradar_key, rega_ac_regs_string, save_path_root, start_date, end_date, splits_per_hour)
#      49 print(f"Requesting on date {date} at timestamp {timestamp}")
#      51 try:
# ---> 52     response = requests.get(url, headers=headers, params=params)
#      53     response.raise_for_status()
#      54     data = response.json()
#
# File ~/anaconda3/envs/flight_lab/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/anaconda3/envs/flight_lab/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/envs/flight_lab/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/flight_lab/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/flight_lab/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/envs/flight_lab/lib/python3.10/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/anaconda3/envs/flight_lab/lib/python3.10/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/anaconda3/envs/flight_lab/lib/python3.10/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File ~/anaconda3/envs/flight_lab/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~/anaconda3/envs/flight_lab/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/anaconda3/envs/flight_lab/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/anaconda3/envs/flight_lab/lib/python3.10/socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# File ~/anaconda3/envs/flight_lab/lib/python3.10/ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/flight_lab/lib/python3.10/ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df1 = pd.read_csv("../data/raw/df_flight_position_20240101_20241231_2024-05-12 23:00:00_1738403045.csv")
df2 = pd.read_csv("../data/raw/df_flight_position_202405013_20241231_2024-11-17 23:00:00_1738489014.csv")
df3 = pd.read_csv("../data/raw/df_flight_position_20241118_20250131_12_splitsperhour_final_1738513140.csv")
df4 = pd.read_csv("../data/raw/df_flight_position_20221201_20231231_2023-05-10 23:00:00_1738568568.csv")
df5 = pd.read_csv("../data/raw/df_flight_position_20221201_20231231_2023-11-15 23:00:00_1738663321.csv")

# Append df1 and df2
df = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202416 entries, 0 to 202415
# Data columns (total 22 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   fr24_id       202416 non-null  object
#  1   flight        185665 non-null  object
#  2   callsign      201967 non-null  object
#  3   lat           202416 non-null  float64
#  4   lon           202416 non-null  float64
#  5   track         202416 non-null  int64
#  6   alt           202416 non-null  int64
#  7   gspeed        202416 non-null  int64
#  8   vspeed        202416 non-null  int64
#  9   squawk        202416 non-null  int64
#  10  timestamp     202416 non-null  object
#  11  source        202416 non-null  object
#  12  hex           202416 non-null  object
#  13  type          202416 non-null  object
#  14  reg           202416 non-null  object
#  15  painted_as    200513 non-null  object
#  16  operating_as  200513 non-null  object
#  17  orig_iata     171097 non-null  object
#  18  orig_icao     171097 non-null  object
#  19  dest_iata     104078 non-null  object
#  20  dest_icao     104078 non-null  object
#  21  eta           96909 non-null   object
# dtypes: float64(2), int64(5), object(15)
# memory usage: 34.0+ MB
#          fr24_id flight callsign       lat       lon  track   alt  gspeed  \
# 0       337327d8   RGA2    RGA02  47.65457   7.52488      8  2575     124
# 1       337327d8   RGA2    RGA02  47.82994   7.66921     40  2525     154
# 2       337327d8   RGA2    RGA02  48.00197   7.85825     45  3500     144
# 3       337327d8   RGA2    RGA02  48.12985   8.04826    213  3200      21
# 4       33733dd4   RGA2    RGA02  48.07436   7.92854    233  3025      86
# ...          ...    ...      ...       ...       ...    ...   ...     ...
# 202411  32d8b704  SAZ74    SAZ74  41.08882 -75.14168    114  8575     312
# 202412  32d8b704  SAZ74    SAZ74  41.03737 -74.63141    103  3525     291
# 202413  32d8b704  SAZ74    SAZ74  41.04739 -74.11976    111  2625     236
# 202414  32d8b704  SAZ74    SAZ74  40.86341 -74.05853    183     0     112
# 202415  32d947da   RGA7    RGA07  47.17427   9.44882    188     0       1
#
#         vspeed  squawk  ...     hex  type     reg painted_as operating_as  \
# 0         -448    7100  ...  4B43B1  EC45  HB-ZQN        RGA          RGA
# 1            0    7100  ...  4B43B1  EC45  HB-ZQN        RGA          RGA
# 2          576    7100  ...  4B43B1  EC45  HB-ZQN        RGA          RGA
# 3         -640    7100  ...  4B43B1  EC45  HB-ZQN        RGA          RGA
# 4         -128    7100  ...  4B43B1  EC45  HB-ZQN        RGA          RGA
# ...        ...     ...  ...     ...   ...     ...        ...          ...
# 202411   -1792    6073  ...  4B1A02  CL60  HB-JWC        SAZ          RGA
# 202412    -896    6073  ...  4B1A02  CL60  HB-JWC        SAZ          RGA
# 202413    -128    6073  ...  4B1A02  CL60  HB-JWC        SAZ          RGA
# 202414    -640    6073  ...  4B1A02  CL60  HB-JWC        SAZ          RGA
# 202415       0    7100  ...  4B43AC  EC45  HB-ZQI        RGA          RGA
#
#        orig_iata orig_icao dest_iata dest_icao                   eta
# 0            BSL      LFSB       NaN       NaN                   NaN
# 1            BSL      LFSB       NaN       NaN                   NaN
# 2            BSL      LFSB       NaN       NaN                   NaN
# 3            BSL      LFSB       NaN       NaN                   NaN
# 4            QCF      EDTF       NaN       NaN                   NaN
# ...          ...       ...       ...       ...                   ...
# 202411       SLC      KSLC       TEB      KTEB  2023-11-15T22:39:49Z
# 202412       SLC      KSLC       TEB      KTEB  2023-11-15T22:38:09Z
# 202413       SLC      KSLC       TEB      KTEB  2023-11-15T22:42:39Z
# 202414       SLC      KSLC       TEB      KTEB  2023-11-15T22:44:33Z
# 202415       NaN       NaN       NaN       NaN                   NaN
#
# [202416 rows x 22 columns]

# %% [markdown]
# #### Flight tracks
#
# - Need to think of how to organize data, think IGC where each row encodes all information and each column is one flight
# - Analyze (time permitting) to extract mission duration information
#
# **NOTE: Squawk 7100 is used for SAR by REGA**

# %%
def rega_flight_track(flightradar_key,save_path_root,rega_flight_positions_path) :
  # API Parameters
  API_TOKEN = flightradar_key
  url = "https://fr24api.flightradar24.com/api/flight-tracks"

  headers = {
      'Accept': 'application/json',
      'Accept-Version': 'v1',
      'Authorization': f'Bearer {API_TOKEN}',
      }
  
  # Define Save Path
  progress_save_path = "../data/raw" + "/progress_and_errors" + save_path_root.split("../data/raw")[1]
  last_progress_save = "No progress save yet"

  # Flight ID extraction
  rega_flight_positions = pd.read_csv(rega_flight_positions_path)
  flight_ids = list(rega_flight_positions['fr24_id'].unique())

  # Initialize the DataFrame to store data
  df_flight_track = pd.DataFrame(columns=["flight_id", "mission"]).set_index("flight_id")

  # FR_24 ID Based Request Loop
  for i, flight_id in enumerate(flight_ids) :
    # API Parameterization with FR_24 ID and Wait Time
    time.sleep(0.67) 
    params = {
      'flight_id': flight_id #	Aircraft registration numbers (comma-separated values)
    }

    # Debugging line
    clear_output(wait=True)    
    print(f"Request number {i+1} of {len(flight_ids)}, requesting for flight_id {flight_id}") 

    try:  
      response = requests.get(url, headers=headers, params=params)
      response.raise_for_status()
      data = response.json()
      print(json.dumps(data, indent=4))
      
      if isinstance(data[0], dict) and "tracks" in data[0] and isinstance(data[0]["tracks"], list) and data[0]["tracks"] :        
        # If data is found, append it to the DataFrame
        tracks_data = data[0]["tracks"]  
        df_flight_track.loc[flight_id] = [tracks_data]

      else:
        print(f"No data found for flight_id {flight_id}")

    except requests.exceptions.HTTPError as http_err:
      print(f"HTTP error occurred: {http_err}")
      time_of_error = int(time.time())
      save_path = progress_save_path + str(time_of_error) + "_http_error.csv"
      df_flight_track.to_csv(save_path, index=False)

    except Exception as err:
      print(f"An error occurred: {err}")
      time_of_error = int(time.time())
      save_path = progress_save_path + str(time_of_error) + "_error.csv"
      df_flight_track.to_csv(save_path, index=False)

    # In loop progress saving for every 100th mission date range
    if (i+1) % 400 == 0 :
      time_of_progress_save = int(time.time())
      save_path = save_path_root + str(date) + "_" + str(time_of_progress_save) + ".csv"
      df_flight_track.to_csv(save_path, index=False)
      last_progress_save = f"The last progress save was on the {i+1}th mission at {str(time_of_progress_save)}"
      

  # Final Saving
  time_of_run = int(time.time())
  save_path = save_path_root + "final_" + str(time_of_run) + ".csv"
  df_flight_track.to_csv(save_path, index=False)

  print("GREAT SUCCESS!!!!!!!!!!")
  return df_flight_track

# %%
rega_flight_positions_path = "../data/raw/df_flight_position_start_end_final_12324513.csv"
save_path_root = "../data/raw/df_flight_tracks_start_end_" # No need to end with .csv, leave as "_" for timestamp
# rega_flight_tracks = rega_flight_track(flightradar_key,save_path_root,rega_flight_positions_path)
# Out:
# Request number 10 of 10, requesting for flight_id 3877f9db
# [
#     {
#         "fr24_id": "3877f9db",
#         "tracks": [
#             {
#                 "timestamp": "2024-12-24T12:05:50Z",
#                 "lat": 46.2215,
#                 "lon": 7.34523,
#                 "alt": 0,
#                 "gspeed": 5,
#                 "vspeed": 768,
#                 "track": 36,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:05:58Z",
#                 "lat": 46.22186,
#                 "lon": 7.34539,
#                 "alt": 0,
#                 "gspeed": 9,
#                 "vspeed": 704,
#                 "track": 12,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:06:37Z",
#                 "lat": 46.21939,
#                 "lon": 7.33183,
#                 "alt": 0,
#                 "gspeed": 89,
#                 "vspeed": 1024,
#                 "track": 255,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:06:43Z",
#                 "lat": 46.21893,
#                 "lon": 7.32855,
#                 "alt": 0,
#                 "gspeed": 87,
#                 "vspeed": 1152,
#                 "track": 268,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:06:45Z",
#                 "lat": 46.21893,
#                 "lon": 7.32767,
#                 "alt": 0,
#                 "gspeed": 86,
#                 "vspeed": 1216,
#                 "track": 272,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:06:49Z",
#                 "lat": 46.21902,
#                 "lon": 7.32681,
#                 "alt": 0,
#                 "gspeed": 85,
#                 "vspeed": 1152,
#                 "track": 279,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:06:52Z",
#                 "lat": 46.22018,
#                 "lon": 7.32335,
#                 "alt": 1925,
#                 "gspeed": 82,
#                 "vspeed": 1088,
#                 "track": 304,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:06:55Z",
#                 "lat": 46.22076,
#                 "lon": 7.32225,
#                 "alt": 2000,
#                 "gspeed": 80,
#                 "vspeed": 1152,
#                 "track": 306,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:06:57Z",
#                 "lat": 46.22108,
#                 "lon": 7.32165,
#                 "alt": 2025,
#                 "gspeed": 79,
#                 "vspeed": 1216,
#                 "track": 307,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:06:59Z",
#                 "lat": 46.22181,
#                 "lon": 7.3204,
#                 "alt": 2075,
#                 "gspeed": 78,
#                 "vspeed": 1088,
#                 "track": 309,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:07:02Z",
#                 "lat": 46.22246,
#                 "lon": 7.31923,
#                 "alt": 2125,
#                 "gspeed": 78,
#                 "vspeed": 1024,
#                 "track": 309,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:07:04Z",
#                 "lat": 46.22296,
#                 "lon": 7.31837,
#                 "alt": 2200,
#                 "gspeed": 78,
#                 "vspeed": 1216,
#                 "track": 309,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:07:07Z",
#                 "lat": 46.22356,
#                 "lon": 7.31736,
#                 "alt": 2275,
#                 "gspeed": 77,
#                 "vspeed": 2048,
#                 "track": 310,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:07:09Z",
#                 "lat": 46.22404,
#                 "lon": 7.31655,
#                 "alt": 2275,
#                 "gspeed": 79,
#                 "vspeed": 1216,
#                 "track": 309,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:07:12Z",
#                 "lat": 46.22456,
#                 "lon": 7.31559,
#                 "alt": 2350,
#                 "gspeed": 79,
#                 "vspeed": 1216,
#                 "track": 307,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:07:16Z",
#                 "lat": 46.22567,
#                 "lon": 7.31346,
#                 "alt": 2475,
#                 "gspeed": 81,
#                 "vspeed": 1344,
#                 "track": 306,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:07:18Z",
#                 "lat": 46.22618,
#                 "lon": 7.31243,
#                 "alt": 2525,
#                 "gspeed": 81,
#                 "vspeed": 1344,
#                 "track": 306,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:07:24Z",
#                 "lat": 46.22717,
#                 "lon": 7.31023,
#                 "alt": 2600,
#                 "gspeed": 82,
#                 "vspeed": 1152,
#                 "track": 300,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:07:26Z",
#                 "lat": 46.22772,
#                 "lon": 7.30879,
#                 "alt": 2675,
#                 "gspeed": 81,
#                 "vspeed": 1344,
#                 "track": 299,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:07:28Z",
#                 "lat": 46.22809,
#                 "lon": 7.30785,
#                 "alt": 2700,
#                 "gspeed": 81,
#                 "vspeed": 1280,
#                 "track": 298,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:07:31Z",
#                 "lat": 46.22859,
#                 "lon": 7.30658,
#                 "alt": 2750,
#                 "gspeed": 81,
#                 "vspeed": 1088,
#                 "track": 299,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:07:33Z",
#                 "lat": 46.22905,
#                 "lon": 7.30537,
#                 "alt": 2800,
#                 "gspeed": 81,
#                 "vspeed": 1152,
#                 "track": 299,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:07:37Z",
#                 "lat": 46.22963,
#                 "lon": 7.30378,
#                 "alt": 2875,
#                 "gspeed": 81,
#                 "vspeed": 1088,
#                 "track": 297,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:07:40Z",
#                 "lat": 46.23024,
#                 "lon": 7.30209,
#                 "alt": 2925,
#                 "gspeed": 81,
#                 "vspeed": 1024,
#                 "track": 298,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:07:42Z",
#                 "lat": 46.23061,
#                 "lon": 7.3011,
#                 "alt": 2975,
#                 "gspeed": 80,
#                 "vspeed": 1088,
#                 "track": 297,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:07:45Z",
#                 "lat": 46.23102,
#                 "lon": 7.30001,
#                 "alt": 3000,
#                 "gspeed": 81,
#                 "vspeed": 1024,
#                 "track": 296,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:07:47Z",
#                 "lat": 46.23143,
#                 "lon": 7.29881,
#                 "alt": 3050,
#                 "gspeed": 81,
#                 "vspeed": 1216,
#                 "track": 296,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:07:49Z",
#                 "lat": 46.23172,
#                 "lon": 7.29787,
#                 "alt": 3075,
#                 "gspeed": 81,
#                 "vspeed": 1088,
#                 "track": 296,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:07:52Z",
#                 "lat": 46.2321,
#                 "lon": 7.29684,
#                 "alt": 3125,
#                 "gspeed": 81,
#                 "vspeed": 1216,
#                 "track": 296,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:07:54Z",
#                 "lat": 46.23256,
#                 "lon": 7.29554,
#                 "alt": 3175,
#                 "gspeed": 81,
#                 "vspeed": 1344,
#                 "track": 296,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:08:00Z",
#                 "lat": 46.23359,
#                 "lon": 7.29259,
#                 "alt": 3300,
#                 "gspeed": 81,
#                 "vspeed": 1152,
#                 "track": 296,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:08:07Z",
#                 "lat": 46.23475,
#                 "lon": 7.28915,
#                 "alt": 3425,
#                 "gspeed": 80,
#                 "vspeed": 1216,
#                 "track": 295,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:08:17Z",
#                 "lat": 46.23637,
#                 "lon": 7.2842,
#                 "alt": 3650,
#                 "gspeed": 80,
#                 "vspeed": 1408,
#                 "track": 294,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:08:24Z",
#                 "lat": 46.2375,
#                 "lon": 7.28085,
#                 "alt": 3775,
#                 "gspeed": 80,
#                 "vspeed": 1152,
#                 "track": 295,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:08:33Z",
#                 "lat": 46.23871,
#                 "lon": 7.27693,
#                 "alt": 3950,
#                 "gspeed": 80,
#                 "vspeed": 1344,
#                 "track": 292,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:08:41Z",
#                 "lat": 46.2399,
#                 "lon": 7.27255,
#                 "alt": 4175,
#                 "gspeed": 76,
#                 "vspeed": 1536,
#                 "track": 289,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:08:44Z",
#                 "lat": 46.24015,
#                 "lon": 7.27137,
#                 "alt": 4250,
#                 "gspeed": 75,
#                 "vspeed": 1344,
#                 "track": 289,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:08:51Z",
#                 "lat": 46.24109,
#                 "lon": 7.26786,
#                 "alt": 4425,
#                 "gspeed": 72,
#                 "vspeed": 1536,
#                 "track": 290,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:08:59Z",
#                 "lat": 46.2421,
#                 "lon": 7.26444,
#                 "alt": 4625,
#                 "gspeed": 70,
#                 "vspeed": 1472,
#                 "track": 294,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:09:12Z",
#                 "lat": 46.24416,
#                 "lon": 7.25895,
#                 "alt": 4950,
#                 "gspeed": 72,
#                 "vspeed": 1600,
#                 "track": 303,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:09:18Z",
#                 "lat": 46.2453,
#                 "lon": 7.25674,
#                 "alt": 5100,
#                 "gspeed": 75,
#                 "vspeed": 1408,
#                 "track": 306,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:09:23Z",
#                 "lat": 46.24631,
#                 "lon": 7.25493,
#                 "alt": 5175,
#                 "gspeed": 77,
#                 "vspeed": 1088,
#                 "track": 310,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:09:27Z",
#                 "lat": 46.24751,
#                 "lon": 7.25297,
#                 "alt": 5250,
#                 "gspeed": 78,
#                 "vspeed": 1152,
#                 "track": 311,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:36:03Z",
#                 "lat": 46.34244,
#                 "lon": 6.98918,
#                 "alt": 5325,
#                 "gspeed": 78,
#                 "vspeed": 1088,
#                 "track": 310,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:36:18Z",
#                 "lat": 46.34656,
#                 "lon": 6.98161,
#                 "alt": 5325,
#                 "gspeed": 107,
#                 "vspeed": -128,
#                 "track": 308,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:36:33Z",
#                 "lat": 46.35174,
#                 "lon": 6.97234,
#                 "alt": 5250,
#                 "gspeed": 116,
#                 "vspeed": -512,
#                 "track": 309,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:36:48Z",
#                 "lat": 46.35695,
#                 "lon": 6.96332,
#                 "alt": 5125,
#                 "gspeed": 117,
#                 "vspeed": -384,
#                 "track": 309,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:37:03Z",
#                 "lat": 46.36207,
#                 "lon": 6.95428,
#                 "alt": 5150,
#                 "gspeed": 119,
#                 "vspeed": -128,
#                 "track": 308,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:37:19Z",
#                 "lat": 46.36743,
#                 "lon": 6.94443,
#                 "alt": 5150,
#                 "gspeed": 121,
#                 "vspeed": 0,
#                 "track": 308,
#                 "squawk": "0",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:37:34Z",
#                 "lat": 46.37278,
#                 "lon": 6.93457,
#                 "alt": 5150,
#                 "gspeed": 122,
#                 "vspeed": 128,
#                 "track": 307,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:37:48Z",
#                 "lat": 46.37769,
#                 "lon": 6.92527,
#                 "alt": 5175,
#                 "gspeed": 125,
#                 "vspeed": 64,
#                 "track": 307,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:38:05Z",
#                 "lat": 46.38335,
#                 "lon": 6.91425,
#                 "alt": 5100,
#                 "gspeed": 125,
#                 "vspeed": -384,
#                 "track": 306,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:38:19Z",
#                 "lat": 46.38852,
#                 "lon": 6.90415,
#                 "alt": 4975,
#                 "gspeed": 130,
#                 "vspeed": -448,
#                 "track": 306,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:38:29Z",
#                 "lat": 46.39177,
#                 "lon": 6.89783,
#                 "alt": 4875,
#                 "gspeed": 128,
#                 "vspeed": -640,
#                 "track": 306,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:38:38Z",
#                 "lat": 46.39503,
#                 "lon": 6.89152,
#                 "alt": 4800,
#                 "gspeed": 126,
#                 "vspeed": -448,
#                 "track": 306,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:38:47Z",
#                 "lat": 46.3981,
#                 "lon": 6.88568,
#                 "alt": 4750,
#                 "gspeed": 124,
#                 "vspeed": -448,
#                 "track": 307,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:38:56Z",
#                 "lat": 46.40144,
#                 "lon": 6.87938,
#                 "alt": 4650,
#                 "gspeed": 124,
#                 "vspeed": -512,
#                 "track": 307,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:39:05Z",
#                 "lat": 46.4046,
#                 "lon": 6.87335,
#                 "alt": 4600,
#                 "gspeed": 126,
#                 "vspeed": -576,
#                 "track": 306,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:39:14Z",
#                 "lat": 46.40783,
#                 "lon": 6.86721,
#                 "alt": 4525,
#                 "gspeed": 127,
#                 "vspeed": -512,
#                 "track": 307,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:39:23Z",
#                 "lat": 46.41095,
#                 "lon": 6.86117,
#                 "alt": 4425,
#                 "gspeed": 127,
#                 "vspeed": -576,
#                 "track": 307,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:39:32Z",
#                 "lat": 46.41412,
#                 "lon": 6.85526,
#                 "alt": 4350,
#                 "gspeed": 127,
#                 "vspeed": -576,
#                 "track": 307,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:39:44Z",
#                 "lat": 46.41859,
#                 "lon": 6.84675,
#                 "alt": 4250,
#                 "gspeed": 126,
#                 "vspeed": -576,
#                 "track": 306,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:39:54Z",
#                 "lat": 46.42186,
#                 "lon": 6.84046,
#                 "alt": 4175,
#                 "gspeed": 127,
#                 "vspeed": -384,
#                 "track": 306,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:40:03Z",
#                 "lat": 46.42506,
#                 "lon": 6.8343,
#                 "alt": 4100,
#                 "gspeed": 128,
#                 "vspeed": -640,
#                 "track": 306,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:40:12Z",
#                 "lat": 46.42846,
#                 "lon": 6.82773,
#                 "alt": 4025,
#                 "gspeed": 132,
#                 "vspeed": -576,
#                 "track": 306,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:40:21Z",
#                 "lat": 46.43176,
#                 "lon": 6.82134,
#                 "alt": 3950,
#                 "gspeed": 133,
#                 "vspeed": -448,
#                 "track": 306,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:40:30Z",
#                 "lat": 46.43532,
#                 "lon": 6.81454,
#                 "alt": 3875,
#                 "gspeed": 134,
#                 "vspeed": -576,
#                 "track": 307,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:40:41Z",
#                 "lat": 46.43925,
#                 "lon": 6.8069,
#                 "alt": 3800,
#                 "gspeed": 134,
#                 "vspeed": -320,
#                 "track": 307,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:40:48Z",
#                 "lat": 46.44196,
#                 "lon": 6.80177,
#                 "alt": 3725,
#                 "gspeed": 132,
#                 "vspeed": -512,
#                 "track": 307,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:40:57Z",
#                 "lat": 46.4453,
#                 "lon": 6.79531,
#                 "alt": 3650,
#                 "gspeed": 132,
#                 "vspeed": -384,
#                 "track": 306,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:41:06Z",
#                 "lat": 46.44833,
#                 "lon": 6.78941,
#                 "alt": 3550,
#                 "gspeed": 132,
#                 "vspeed": -512,
#                 "track": 306,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:41:14Z",
#                 "lat": 46.45152,
#                 "lon": 6.78325,
#                 "alt": 3500,
#                 "gspeed": 133,
#                 "vspeed": -640,
#                 "track": 306,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:41:24Z",
#                 "lat": 46.45528,
#                 "lon": 6.77595,
#                 "alt": 3425,
#                 "gspeed": 132,
#                 "vspeed": -512,
#                 "track": 307,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:41:31Z",
#                 "lat": 46.4577,
#                 "lon": 6.77119,
#                 "alt": 3375,
#                 "gspeed": 133,
#                 "vspeed": -448,
#                 "track": 306,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:41:42Z",
#                 "lat": 46.46173,
#                 "lon": 6.76342,
#                 "alt": 3275,
#                 "gspeed": 134,
#                 "vspeed": -384,
#                 "track": 306,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:41:52Z",
#                 "lat": 46.46539,
#                 "lon": 6.75619,
#                 "alt": 3200,
#                 "gspeed": 134,
#                 "vspeed": -320,
#                 "track": 306,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:42:01Z",
#                 "lat": 46.46851,
#                 "lon": 6.75016,
#                 "alt": 3150,
#                 "gspeed": 133,
#                 "vspeed": -192,
#                 "track": 306,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:42:09Z",
#                 "lat": 46.47179,
#                 "lon": 6.74368,
#                 "alt": 3175,
#                 "gspeed": 132,
#                 "vspeed": 0,
#                 "track": 306,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:42:18Z",
#                 "lat": 46.47478,
#                 "lon": 6.73783,
#                 "alt": 3150,
#                 "gspeed": 134,
#                 "vspeed": -128,
#                 "track": 306,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:42:25Z",
#                 "lat": 46.47743,
#                 "lon": 6.7327,
#                 "alt": 3150,
#                 "gspeed": 136,
#                 "vspeed": 192,
#                 "track": 306,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:42:34Z",
#                 "lat": 46.48096,
#                 "lon": 6.72576,
#                 "alt": 3150,
#                 "gspeed": 138,
#                 "vspeed": -64,
#                 "track": 306,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:42:44Z",
#                 "lat": 46.4846,
#                 "lon": 6.71869,
#                 "alt": 3150,
#                 "gspeed": 135,
#                 "vspeed": 0,
#                 "track": 306,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:42:53Z",
#                 "lat": 46.4879,
#                 "lon": 6.7121,
#                 "alt": 3125,
#                 "gspeed": 135,
#                 "vspeed": 0,
#                 "track": 305,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:42:59Z",
#                 "lat": 46.48997,
#                 "lon": 6.70755,
#                 "alt": 3100,
#                 "gspeed": 137,
#                 "vspeed": -256,
#                 "track": 301,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:43:02Z",
#                 "lat": 46.49102,
#                 "lon": 6.70489,
#                 "alt": 3075,
#                 "gspeed": 138,
#                 "vspeed": -384,
#                 "track": 298,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:43:05Z",
#                 "lat": 46.49191,
#                 "lon": 6.70235,
#                 "alt": 3050,
#                 "gspeed": 140,
#                 "vspeed": -640,
#                 "track": 296,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:43:08Z",
#                 "lat": 46.49274,
#                 "lon": 6.69967,
#                 "alt": 3025,
#                 "gspeed": 140,
#                 "vspeed": -512,
#                 "track": 294,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:43:11Z",
#                 "lat": 46.49355,
#                 "lon": 6.69697,
#                 "alt": 3000,
#                 "gspeed": 140,
#                 "vspeed": -704,
#                 "track": 293,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:43:14Z",
#                 "lat": 46.49432,
#                 "lon": 6.69429,
#                 "alt": 2950,
#                 "gspeed": 141,
#                 "vspeed": -640,
#                 "track": 292,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:43:17Z",
#                 "lat": 46.49492,
#                 "lon": 6.69208,
#                 "alt": 2950,
#                 "gspeed": 140,
#                 "vspeed": -512,
#                 "track": 291,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:43:20Z",
#                 "lat": 46.49574,
#                 "lon": 6.68907,
#                 "alt": 2900,
#                 "gspeed": 140,
#                 "vspeed": -768,
#                 "track": 291,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:43:23Z",
#                 "lat": 46.49648,
#                 "lon": 6.68645,
#                 "alt": 2875,
#                 "gspeed": 139,
#                 "vspeed": -704,
#                 "track": 291,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:43:26Z",
#                 "lat": 46.49721,
#                 "lon": 6.68391,
#                 "alt": 2850,
#                 "gspeed": 138,
#                 "vspeed": -448,
#                 "track": 293,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:43:31Z",
#                 "lat": 46.49858,
#                 "lon": 6.67955,
#                 "alt": 2800,
#                 "gspeed": 137,
#                 "vspeed": -384,
#                 "track": 295,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:43:41Z",
#                 "lat": 46.50145,
#                 "lon": 6.67117,
#                 "alt": 2700,
#                 "gspeed": 138,
#                 "vspeed": -512,
#                 "track": 297,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:43:44Z",
#                 "lat": 46.50229,
#                 "lon": 6.66884,
#                 "alt": 2700,
#                 "gspeed": 137,
#                 "vspeed": -576,
#                 "track": 296,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:43:47Z",
#                 "lat": 46.50311,
#                 "lon": 6.66636,
#                 "alt": 2675,
#                 "gspeed": 137,
#                 "vspeed": -448,
#                 "track": 296,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:43:50Z",
#                 "lat": 46.50401,
#                 "lon": 6.66376,
#                 "alt": 2625,
#                 "gspeed": 137,
#                 "vspeed": -448,
#                 "track": 296,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:43:53Z",
#                 "lat": 46.50481,
#                 "lon": 6.6614,
#                 "alt": 2575,
#                 "gspeed": 137,
#                 "vspeed": -896,
#                 "track": 296,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:43:59Z",
#                 "lat": 46.50668,
#                 "lon": 6.65637,
#                 "alt": 2500,
#                 "gspeed": 135,
#                 "vspeed": -1216,
#                 "track": 299,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:44:02Z",
#                 "lat": 46.50755,
#                 "lon": 6.65435,
#                 "alt": 2425,
#                 "gspeed": 132,
#                 "vspeed": -1344,
#                 "track": 302,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:44:05Z",
#                 "lat": 46.50866,
#                 "lon": 6.65208,
#                 "alt": 2375,
#                 "gspeed": 128,
#                 "vspeed": -1472,
#                 "track": 306,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:44:09Z",
#                 "lat": 46.50983,
#                 "lon": 6.64996,
#                 "alt": 2275,
#                 "gspeed": 124,
#                 "vspeed": -1344,
#                 "track": 310,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:44:11Z",
#                 "lat": 46.51085,
#                 "lon": 6.64838,
#                 "alt": 2225,
#                 "gspeed": 122,
#                 "vspeed": -1536,
#                 "track": 314,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:44:15Z",
#                 "lat": 46.51208,
#                 "lon": 6.64679,
#                 "alt": 2125,
#                 "gspeed": 117,
#                 "vspeed": -1600,
#                 "track": 318,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:44:17Z",
#                 "lat": 46.51341,
#                 "lon": 6.64532,
#                 "alt": 2050,
#                 "gspeed": 110,
#                 "vspeed": -1536,
#                 "track": 323,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:44:21Z",
#                 "lat": 46.51442,
#                 "lon": 6.64438,
#                 "alt": 1975,
#                 "gspeed": 103,
#                 "vspeed": -1408,
#                 "track": 329,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:44:24Z",
#                 "lat": 46.51598,
#                 "lon": 6.64325,
#                 "alt": 1925,
#                 "gspeed": 97,
#                 "vspeed": -1472,
#                 "track": 334,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:44:27Z",
#                 "lat": 46.51717,
#                 "lon": 6.64257,
#                 "alt": 1850,
#                 "gspeed": 91,
#                 "vspeed": -1088,
#                 "track": 340,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:44:30Z",
#                 "lat": 46.51835,
#                 "lon": 6.64206,
#                 "alt": 1800,
#                 "gspeed": 82,
#                 "vspeed": -1280,
#                 "track": 345,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:44:33Z",
#                 "lat": 46.51937,
#                 "lon": 6.64172,
#                 "alt": 1775,
#                 "gspeed": 79,
#                 "vspeed": -1088,
#                 "track": 346,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:44:36Z",
#                 "lat": 46.5204,
#                 "lon": 6.64151,
#                 "alt": 1725,
#                 "gspeed": 70,
#                 "vspeed": -768,
#                 "track": 351,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:44:39Z",
#                 "lat": 46.52124,
#                 "lon": 6.64137,
#                 "alt": 1700,
#                 "gspeed": 63,
#                 "vspeed": -768,
#                 "track": 354,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:44:42Z",
#                 "lat": 46.52202,
#                 "lon": 6.6413,
#                 "alt": 1650,
#                 "gspeed": 54,
#                 "vspeed": -576,
#                 "track": 355,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:44:48Z",
#                 "lat": 46.52312,
#                 "lon": 6.6413,
#                 "alt": 1625,
#                 "gspeed": 35,
#                 "vspeed": -384,
#                 "track": 3,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:44:53Z",
#                 "lat": 46.52393,
#                 "lon": 6.6413,
#                 "alt": 1575,
#                 "gspeed": 24,
#                 "vspeed": -448,
#                 "track": 3,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:44:57Z",
#                 "lat": 46.52426,
#                 "lon": 6.64123,
#                 "alt": 1575,
#                 "gspeed": 34,
#                 "vspeed": -384,
#                 "track": 3,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             },
#             {
#                 "timestamp": "2024-12-24T12:45:04Z",
#                 "lat": 46.52449,
#                 "lon": 6.6411,
#                 "alt": 1575,
#                 "gspeed": 11,
#                 "vspeed": 0,
#                 "track": 333,
#                 "squawk": "7100",
#                 "callsign": "RGA18",
#                 "source": "ADSB"
#             }
#         ]
#     }
# ]
# GREAT SUCCESS!!!!!!!!!!

# %%
rega_flight_tracks
# Out:
#                                                     missions
# flight_id
# 387701e5   [{'timestamp': '2024-12-24T02:32:06Z', 'lat': ...
# 3877897e   [{'timestamp': '2024-12-24T07:50:50Z', 'lat': ...
# 387795d7   [{'timestamp': '2024-12-24T08:20:54Z', 'lat': ...
# 38779e5a   [{'timestamp': '2024-12-24T08:47:33Z', 'lat': ...
# 3877dab0   [{'timestamp': '2024-12-24T11:00:36Z', 'lat': ...
# 3877e7e1   [{'timestamp': '2024-12-24T11:27:13Z', 'lat': ...
# 3877ec82   [{'timestamp': '2024-12-24T11:37:37Z', 'lat': ...
# 3877efb5   [{'timestamp': '2024-12-24T11:44:17Z', 'lat': ...
# 3877f25b   [{'timestamp': '2024-12-24T11:49:47Z', 'lat': ...
# 3877f9db   [{'timestamp': '2024-12-24T12:05:50Z', 'lat': ...

# %%
single_track_example = pd.DataFrame(rega_flight_tracks.loc['387701e5'].values[0])
single_track_example
# Out:
#                 timestamp       lat      lon   alt  gspeed  vspeed  track  \
# 0    2024-12-24T02:32:06Z  46.54710  6.61792     0       0     832    270
# 1    2024-12-24T02:32:14Z  46.54683  6.61765     0      11     192    210
# 2    2024-12-24T02:32:21Z  46.54610  6.61732     0      47     128    194
# 3    2024-12-24T02:32:27Z  46.54362  6.61652     0      76     512    192
# 4    2024-12-24T02:32:30Z  46.54253  6.61618     0      82     512    190
# ..                    ...       ...      ...   ...     ...     ...    ...
# 129  2024-12-24T02:43:24Z  46.54573  6.61698  1750      39    -320     13
# 130  2024-12-24T02:43:27Z  46.54619  6.61719  1750      33    -192     21
# 131  2024-12-24T02:43:31Z  46.54660  6.61748  1725      25    -256     30
# 132  2024-12-24T02:43:34Z  46.54688  6.61775  1725      17    -192     38
# 133  2024-12-24T02:43:38Z  46.54702  6.61796  1725       9     128     45
#
#     squawk callsign source
# 0        0    RGA04   ADSB
# 1        0    RGA04   ADSB
# 2        0    RGA04   ADSB
# 3        0    RGA04   ADSB
# 4        0    RGA04   ADSB
# ..     ...      ...    ...
# 129   7100    RGA04   ADSB
# 130   7100    RGA04   ADSB
# 131   7100    RGA04   ADSB
# 132   7100    RGA04   ADSB
# 133   7100    RGA04   ADSB
#
# [134 rows x 10 columns]
